# %% [markdown]
# # California Medicaid Eligibility Groups by Medi-Cal Aid Code

# %% [markdown]
# ## Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Medicaid_clean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 AID CODE                                      AID CODE NAME  \
# 0           2       03                  Adoption Assistance Program (AAP)
# 1           3       04  Adoption Assistance Program (AAP)/Aid for Adop...
# 2           5       06          Adoption Assistance Program (AAP) - Child
# 3           6       07  Adoption Assistance Program (AAP) - Title IV-E...
# 4           9       10  Aged - Supplemental Security Income/State Supp...
#
#               BENEFITS                                  ELIGIBILITY GROUP  \
# 0  Full Scope (No SOC)  Children with Title IV-E Adoption Assistance, ...
# 1  Full Scope (No SOC)         Children with Non-IV-E Adoption Assistance
# 2  Full Scope (No SOC)  Children with Title IV-E Adoption Assistance, ...
# 3  Full Scope (No SOC)  Children with Title IV-E Adoption Assistance, ...
# 4  Full Scope (No SOC)                          Individuals Receiving SSI
#
#                                    SHORT DESCRIPTION  GROUP CODE  \
# ...

# %%
df = df.drop(columns="Unnamed: 0")

# %%
df.head()
# Out:
#   AID CODE                                      AID CODE NAME  \
# 0       03                  Adoption Assistance Program (AAP)
# 1       04  Adoption Assistance Program (AAP)/Aid for Adop...
# 2       06          Adoption Assistance Program (AAP) - Child
# 3       07  Adoption Assistance Program (AAP) - Title IV-E...
# 4       10  Aged - Supplemental Security Income/State Supp...
#
#               BENEFITS                                  ELIGIBILITY GROUP  \
# 0  Full Scope (No SOC)  Children with Title IV-E Adoption Assistance, ...
# 1  Full Scope (No SOC)         Children with Non-IV-E Adoption Assistance
# 2  Full Scope (No SOC)  Children with Title IV-E Adoption Assistance, ...
# 3  Full Scope (No SOC)  Children with Title IV-E Adoption Assistance, ...
# 4  Full Scope (No SOC)                          Individuals Receiving SSI
#
#                                    SHORT DESCRIPTION  GROUP CODE  \
# 0  Individuals for whom an adoption assistance ag...           8
# ...

# %%
df["BENEFITS"].value_counts()
# Out:
# Full Scope (No SOC)                     156
# Restricted or Limited (No SOC)           84
# Restricted or Limited (SOC)              22
# Full Scope (SOC)                         18
# No Medi-Cal Benefits                      4
# Full Scope (SOC/No SOC)                   4
# Restricted or Limited (SOC/No SOC)        2
# Restricted or Limited Scope (No SOC)      1
# Name: BENEFITS, dtype: int64

# %%
df["BENEFITS"].value_counts().plot(kind='barh')

# %%
plt.figure(figsize=(16,12))
df["ELIGIBILITY GROUP"].value_counts().plot(kind='barh')

# %%
df["ELIGIBILITY GROUP"].value_counts()
# Out:
# Medically Needy Aged, Blind or Disabled                                                  52
# Infants and Children under Age 19                                                        28
# Parents and Other Caretaker Relatives                                                    26
# Optional Targeted Low Income Children                                                    24
# Adult Group - Individuals at or below 133% FPL Age 19 through 64 - newly eligible        16
# Medically Needy Children under Age 18                                                    14
# Medically Needy Children Age 18 through 20                                               14
# Medically Needy Pregnant Women                                                           13
# Reasonable Classifications of Individuals Under Age 21                                   13
# Children with Title IV-E Adoption Assistance, Foster Care or Guardianship Care           12
# ...

# %%
df["MEDICAID \nOR CHIP"].value_counts()
# Out:
# Medicaid    255
# MCHIP        30
# SCHIP         6
# Name: MEDICAID \nOR CHIP, dtype: int64

# %%
df["MEDICAID \nOR CHIP"].value_counts().plot(kind='barh')

# %%
df["GROUP CODE"].value_counts()
# Out:
# 59    52
# 7     28
# 1     26
# 31    24
# 72    16
# 54    14
# 55    14
# 28    13
# 53    13
# 8     12
# 5     11
# 34     9
# 46     6
# 73     6
# 56     4
# 2      4
# 21     4
# 11     3
# 18     3
# 29     3
# 64     3
# 61     3
# 9      2
# 4      2
# 22     2
# 6      2
# 52     2
# 26     1
# 47     1
# 36     1
# 25     1
# 35     1
# 19     1
# 30     1
# 23     1
# 24     1
# 76     1
# Name: GROUP CODE, dtype: int64

# %%
df["TYPE"].value_counts().plot(kind='barh')

# %%
df["TYPE"].value_counts()
# Out:
# Family/Adult    207
# ABD              78
# Children          6
# Name: TYPE, dtype: int64

# %%
df["FEDERAL CATEGORY"].value_counts()
# Out:
# Mandatory            126
# Medically Needy       97
# Optional              62
# SCHIP                  6
# Name: FEDERAL CATEGORY, dtype: int64

# %%
df["FEDERAL CATEGORY"].value_counts().plot(kind='barh')

# %%
df["FEDERAL CATEGORY"].value_counts()
# Out:
# Mandatory            126
# Medically Needy       97
# Optional              62
# SCHIP                  6
# Name: FEDERAL CATEGORY, dtype: int64

# %%
df["SOCIAL SECURITY ACT \nCITATION"].value_counts()
# Out:
# 1902(a)(10)(C)                                                                                     52
# 1902(a)(10)(C)(ii)(II)                                                                             41
# 1902(a)(10)(A)(i)(III), (IV), (VI), and (VII); 1902(a)(10)(A)(ii)(IV) and (IX); 1931(b) and (d)    28
# 1902(a)(10)(A)(i)(I); 1931(b) and (d)                                                              26
# 1902(a)(10)(A)(ii)(XIV); 1905(u)(2)(B)                                                             24
# 1902(a)(10)(A)(i)(VIII)                                                                            16
# 1902(a)(10)(A)(ii)(I) and (IV)                                                                     13
# 1902(a)(10)(A)(i)(I)                                                                               12
# 1902(a)(10)(A)(i)(III) and (IV); 1902(a)(10)(A)(ii)(I), (IV), and (IX); 1931(b) and (d)            11
# ...

# %%
df["CODE OF FEDERAL REGULATIONS\nCITATION"].value_counts()
# Out:
# 42 CFR 435.118                      28
# 42 CFR 435.110                      26
# 0                                   24
# 42 CFR 435.229 and 435.4            24
# 42 CFR 435.119                      22
# 42 CFR 435.320, 322 & 324           18
# 42 CFR 435.301(b)(1)(ii)            14
# 42 CFR 435.308                      14
# 42 CFR 435.301(b)(1)(i) and (iv)    13
# 42 CFR 435.222                      13
# 42 CFR 435.145                      12
# 42 CFR 435.324                      12
# 42 CFR 435.320                      11
# 42 CFR 435.116                      11
# 42 CFR 435.322                       9
# 42 CFR 435.213                       9
# 42 CFR 457.310                       6
# 42 CFR 435.310                       4
# 42 CFR 435.120                       3
# 42 CFR 435.135                       3
# 42 CFR 435.227                       3
# 42 CFR 435.117                       2
# 42 CFR 435.115                       2
# 42 CFR 435.150                       2
# ...
