# %%
import pandas as pd

# %%
medicaid_data = pd.read_csv("California_Medicaid_Groups.csv", encoding='cp1252')

# %%
medicaid_data
# Out:
#     AID CODE                                      AID CODE NAME  \
# 0         01  Refugee Resettlement Program (RRP) - Refugee C...
# 1         02  Refugee Resettlement Program (RRP) - Refugee M...
# 2         03                  Adoption Assistance Program (AAP)
# 3         04  Adoption Assistance Program (AAP)/Aid for Adop...
# 4         05                                       SED Children
# ..       ...                                                ...
# 373       X4  Covered California - Modified Adjusted Gross I...
# 374       X5  Covered California - Modified Adjusted Gross I...
# 375       X6  Covered California - American Indian and Alask...
# 376       X7  Covered California - Modified Adjusted Gross I...
# 377       X9  Covered California - Modified Adjusted Gross I...
#
#                     BENEFITS  \
# 0        Full Scope (No SOC)
# 1    Full Scope (SOC/No SOC)
# 2        Full Scope (No SOC)
# 3        Full Scope (No SOC)
# 4       No Medi-Cal Benefits
# ...

# %%
medicaid_data.describe(include='all')
# Out:
#        AID CODE                                      AID CODE NAME  \
# count       378                                                378
# unique      351                                                284
# top          34  Medi-Cal Juvenile County Inmates Hospital Inpa...
# freq          4                                                 12
#
#                    BENEFITS ELIGIBILITY GROUP  \
# count                   378               373
# unique                    8                59
# top     Full Scope (No SOC)      Not Medi-Cal
# freq                    164                56
#
#                                         SHORT DESCRIPTION GROUP CODE  \
# count                                                 316        378
# unique                                                 60         38
# top     Individuals who are age 65 or older, blind or ...          -
# freq                                                   52         87
#
# ...

# %%
include =['object', 'float', 'int'] 
medicaid_data.describe(include = include)
# Out:
#        AID CODE                                      AID CODE NAME  \
# count       378                                                378
# unique      351                                                284
# top          34  Medi-Cal Juvenile County Inmates Hospital Inpa...
# freq          4                                                 12
#
#                    BENEFITS ELIGIBILITY GROUP  \
# count                   378               373
# unique                    8                59
# top     Full Scope (No SOC)      Not Medi-Cal
# freq                    164                56
#
#                                         SHORT DESCRIPTION GROUP CODE  \
# count                                                 316        378
# unique                                                 60         38
# top     Individuals who are age 65 or older, blind or ...          -
# freq                                                   52         87
#
# ...

# %%
medicaid_data.describe()
# Out:
#        AID CODE                                      AID CODE NAME  \
# count       378                                                378
# unique      351                                                284
# top          34  Medi-Cal Juvenile County Inmates Hospital Inpa...
# freq          4                                                 12
#
#                    BENEFITS ELIGIBILITY GROUP  \
# count                   378               373
# unique                    8                59
# top     Full Scope (No SOC)      Not Medi-Cal
# freq                    164                56
#
#                                         SHORT DESCRIPTION GROUP CODE  \
# count                                                 316        378
# unique                                                 60         38
# top     Individuals who are age 65 or older, blind or ...          -
# freq                                                   52         87
#
# ...

# %%
medicaid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   AID CODE                              378 non-null    object
#  1   AID CODE NAME                         378 non-null    object
#  2   BENEFITS                              378 non-null    object
#  3   ELIGIBILITY GROUP                     373 non-null    object
#  4   SHORT DESCRIPTION                     316 non-null    object
#  5   GROUP CODE                            378 non-null    object
#  6   TYPE                                  291 non-null    object
#  7   FEDERAL CATEGORY                      291 non-null    object
#  8   MEDICAID
# OR CHIP                     291 non-null    object
#  9   SOCIAL SECURITY ACT
# CITATION         284 non-null    object
#  10  CODE OF FEDERAL REGULATIONS
# CITATION  267 non-null    object
# ...

# %%
print("Exploratory Data Analysis")
print("Medicaid Data")
print('-'*40)
print("Dataset information") 
print(medicaid_data.info(memory_usage='deep',verbose=False))
print('-'*40)
print(medicaid_data.info())
print('-'*40)
print("Data type:")
print(medicaid_data.dtypes)
print('-'*40)
print("Check unique values without NaN")
print(medicaid_data.nunique())
print('-'*40)
print("Data shape:")
print(medicaid_data.shape)
print('-'*40)
print("Data columns Names:")
print(medicaid_data.columns)
print('-'*40)
print("Check for NaNs:")
print(medicaid_data.isnull().values.any())
print('-'*40)
print("How many NaN it has in each columns?")
print(medicaid_data.isnull().sum())
print('-'*40)
print("Data Statistics Summary:")
print(medicaid_data.describe())
print('\n')
# Out:
# Exploratory Data Analysis
# Medicaid Data
# ----------------------------------------
# Dataset information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Columns: 11 entries, AID CODE to CODE OF FEDERAL REGULATIONS
# CITATION
# dtypes: object(11)
# memory usage: 337.7 KB
# None
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   AID CODE                              378 non-null    object
#  1   AID CODE NAME                         378 non-null    object
#  2   BENEFITS                              378 non-null    object
#  3   ELIGIBILITY GROUP                     373 non-null    object
#  4   SHORT DESCRIPTION                     316 non-null    object
# ...

# %%
pd.set_option('display.max_columns', None)
medicaid_data.head()
# Out:
#   AID CODE                                      AID CODE NAME  \
# 0       01  Refugee Resettlement Program (RRP) - Refugee C...
# 1       02  Refugee Resettlement Program (RRP) - Refugee M...
# 2       03                  Adoption Assistance Program (AAP)
# 3       04  Adoption Assistance Program (AAP)/Aid for Adop...
# 4       05                                       SED Children
#
#                   BENEFITS                                  ELIGIBILITY GROUP  \
# 0      Full Scope (No SOC)                                N/A - do not report
# 1  Full Scope (SOC/No SOC)                                N/A - do not report
# 2      Full Scope (No SOC)  Children with Title IV-E Adoption Assistance, ...
# 3      Full Scope (No SOC)         Children with Non-IV-E Adoption Assistance
# 4     No Medi-Cal Benefits                                       Not Medi-Cal
#
#                                    SHORT DESCRIPTION GROUP CODE          TYPE  \
# ...

# %%
pd.set_option("max_colwidth", None)
medicaid_data[["AID CODE NAME", "SHORT DESCRIPTION"]].head()
# Out:
#                                                                                             AID CODE NAME  \
# 0                     Refugee Resettlement Program (RRP) - Refugee Cash Assistance (RCA) - First 8 months
# 1  Refugee Resettlement Program (RRP) - Refugee Medical Assistance (RMA)/Entrant Medical Assistance (EMA)
# 2                                                                       Adoption Assistance Program (AAP)
# 3                                    Adoption Assistance Program (AAP)/Aid for Adoption of Children (AAC)
# 4                                                                                            SED Children
#
#                                                                                                                                                                                                      SHORT DESCRIPTION
# ...

# %%
pd.set_option("max_rows", None)
medicaid_data[["AID CODE NAME", "SHORT DESCRIPTION"]]
# Out:
#                                                                                                                                                                     AID CODE NAME  \
# 0                                                                                             Refugee Resettlement Program (RRP) - Refugee Cash Assistance (RCA) - First 8 months
# 1                                                                          Refugee Resettlement Program (RRP) - Refugee Medical Assistance (RMA)/Entrant Medical Assistance (EMA)
# 2                                                                                                                                               Adoption Assistance Program (AAP)
# 3                                                                                                            Adoption Assistance Program (AAP)/Aid for Adoption of Children (AAC)
# ...

# %%
# Shows Coolumns with NaN
medicaid_data.loc[:, medicaid_data.isna().any()]
# Out:
#                                                                                           ELIGIBILITY GROUP  \
# 0                                                                                       N/A - do not report
# 1                                                                                       N/A - do not report
# 2                            Children with Title IV-E Adoption Assistance, Foster Care or Guardianship Care
# 3                                                                Children with Non-IV-E Adoption Assistance
# 4                                                                                              Not Medi-Cal
# 5                            Children with Title IV-E Adoption Assistance, Foster Care or Guardianship Care
# 6                            Children with Title IV-E Adoption Assistance, Foster Care or Guardianship Care
# 7                                                                                       N/A - do not report
# ...

# %%
# Remove rows with Not Medi-Cal
data_clean = medicaid_data[medicaid_data["ELIGIBILITY GROUP"] != "Not Medi-Cal"]

# %%
data_clean
# Out:
#     AID CODE  \
# 0         01
# 1         02
# 2         03
# 3         04
# 5         06
# 6         07
# 7         08
# 9         10
# 12        13
# 13        14
# 14        16
# 15        17
# 16        18
# 17        20
# 20        23
# 21        24
# 22        26
# 23        27
# 24        28
# 25        30
# 27        32
# 28        33
# 29        34
# 30        34
# 31        34
# 32        34
# 33        35
# 34        36
# 35        37
# 36        37
# 37        37
# 38        37
# 39        38
# 40        38
# 41        39
# 42        40
# 44        42
# 45        43
# 46        44
# 47        45
# 48        46
# 49        47
# 50        48
# 51        49
# 52        50
# 53        53
# 54        54
# 55        55
# 56        58
# 57        59
# 58        60
# 61        63
# 62        64
# 63        66
# 64        67
# 65        68
# 66        69
# 67        71
# 68        72
# 69        73
# 70        74
# 71        76
# 72        77
# 73        80
# 74        81
# ...
