# %% [markdown]
# # Employment Disability Status Table

# %% [markdown]
# https://www.bls.gov/news.release/disabl.t01.htm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
web ='https://www.bls.gov/news.release/disabl.t01.htm'
d = pd.read_html(web)

# %%
type(d)
# Out:
# list

# %%
len(d)
# Out:
# 1

# %%
df = d[0]
df
# Out:
#                                        Characteristic  \
#                                        Characteristic
#                                        Characteristic
# 0                                               TOTAL
# 1                            Total, 16 years and over
# 2                                                 Men
# 3                                               Women
# 4                                                 NaN
# 5                           PERSONS WITH A DISABILITY
# 6                            Total, 16 years and over
# 7                                                 Men
# 8                                               Women
# 9                                                 Age
# 10                                     16 to 64 years
# 11                                     16 to 19 years
# 12                                     20 to 24 years
# 13                                     25 to 34 years
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
# (Characteristic, Characteristic, Characteristic)                                                                   54 non-null object
# (Civiliannoninsti-tutionalpopulation, Civiliannoninsti-tutionalpopulation, Civiliannoninsti-tutionalpopulation)    45 non-null object
# (Civilian labor force, Total, Total)                                                                               45 non-null object
# (Civilian labor force, Participationrate, Participationrate)                                                       45 non-null object
# (Civilian labor force, Employed, Total)                                                                            45 non-null object
# (Civilian labor force, Employed, Percent ofpopulation)                                                             45 non-null object
# ...

# %%
df = pd.read_html("https://www.bls.gov/news.release/disabl.t01.htm", header=0,parse_dates=['Characteristic'])

# %%
df = df[0]

# %%
df
# Out:
#                                        Characteristic  \
# 0                                      Characteristic
# 1                                      Characteristic
# 2                                               TOTAL
# 3                            Total, 16 years and over
# 4                                                 Men
# 5                                               Women
# 6                                                 NaN
# 7                           PERSONS WITH A DISABILITY
# 8                            Total, 16 years and over
# 9                                                 Men
# 10                                              Women
# 11                                                Age
# 12                                     16 to 64 years
# 13                                     16 to 19 years
# 14                                     20 to 24 years
# 15                                     25 to 34 years
# ...

# %%
df.to_csv("employment_disability.csv", index=False)

# %%
df.describe()
# Out:
#                   Characteristic  Civiliannoninsti-tutionalpopulation  \
# count                         56                                   47
# unique                        29                                   46
# top     Total, 16 years and over  Civiliannoninsti-tutionalpopulation
# freq                           3                                    2
#
#        Civilian labor force Civilian labor force.1 Civilian labor force.2  \
# count                    47                     47                     47
# unique                   46                     44                     47
# top                   Total                   85.2                 141390
# freq                      2                      2                      1
#
#        Civilian labor force.3 Civilian labor force.4 Civilian labor force.5  \
# count                      47                     47                     47
# unique                     46                     47                     34
# ...
