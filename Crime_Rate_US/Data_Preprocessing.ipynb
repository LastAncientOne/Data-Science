# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Crime.xlsx')

# %%
df
# Out:
#                                               Table 1               \
# 0                          Crime in the United States          NaN
# 1   by Volume and Rate per 100,000 Inhabitants, 19...          NaN
# 2                                                Year  Population1
# 3                                                1997    267783607
# 4                                                1998    270248003
# 5                                                1999    272690813
# 6                                                2000    281421906
# 7                                               20015    285317559
# 8                                                2002    287973924
# 9                                                2003    290788976
# 10                                               2004    293656842
# 11                                               2005    296507061
# 12                                               2006    299398484
# ...

# %%
df = df.drop(df.index[23:45])

# %%
df
# Out:
#                                               Table 1               \
# 0                          Crime in the United States          NaN
# 1   by Volume and Rate per 100,000 Inhabitants, 19...          NaN
# 2                                                Year  Population1
# 3                                                1997    267783607
# 4                                                1998    270248003
# 5                                                1999    272690813
# 6                                                2000    281421906
# 7                                               20015    285317559
# 8                                                2002    287973924
# 9                                                2003    290788976
# 10                                               2004    293656842
# 11                                               2005    296507061
# 12                                               2006    299398484
# ...

# %%
df = df.drop(df.index[0:2])

# %%
df
# Out:
#    Table 1                    Unnamed: 2               Unnamed: 3  \
# 2     Year  Population1  Violent\ncrime2  Violent \ncrime \nrate
# 3     1997    267783607          1636096                      611
# 4     1998    270248003          1533887                    567.6
# 5     1999    272690813          1426044                      523
# 6     2000    281421906          1425486                    506.5
# 7    20015    285317559          1439480                    504.5
# 8     2002    287973924          1423677                    494.4
# 9     2003    290788976          1383676                    475.8
# 10    2004    293656842          1360088                    463.2
# 11    2005    296507061          1390745                      469
# 12    2006    299398484          1435123                    479.3
# 13    2007    301621157          1422970                    471.8
# 14    2008    304059724          1394461                    458.6
# ...

# %%
df.columns = ['Year', 'Population', 'Violent Crime', 'Violent Crime Rate', 'Murder and nonnegligent', 'Murder and nonnegligent Rate', 'Rape', 'Rape Rate', 'Rape Legacy', 'Rape Legacy Rate', 'Robbery', 'Robbery Rate', 'Aggravated assault', 'Aggravated assault Rate', 'Property crime', 'Property crime Rate', 'Burglary', 'Burglary Rate', 'Larceny-theft', 'Larceny-theft Rate', 'Motor vehicle theft', 'Motor vehicle theft Rate']

# %%
df = df.drop(df.index[0:1])

# %%
df
# Out:
#      Year Population Violent Crime Violent Crime Rate Murder and nonnegligent  \
# 3    1997  267783607       1636096                611                   18208
# 4    1998  270248003       1533887              567.6                   16974
# 5    1999  272690813       1426044                523                   15522
# 6    2000  281421906       1425486              506.5                   15586
# 7   20015  285317559       1439480              504.5                   16037
# 8    2002  287973924       1423677              494.4                   16229
# 9    2003  290788976       1383676              475.8                   16528
# 10   2004  293656842       1360088              463.2                   16148
# 11   2005  296507061       1390745                469                   16740
# 12   2006  299398484       1435123              479.3                   17309
# 13   2007  301621157       1422970              471.8                   17128
# ...

# %%
# Fix the Year
df.at[7, 'Year'] = 2001 
df.at[21, 'Year'] = 2015

# %%
df
# Out:
#     Year Population Violent Crime Violent Crime Rate Murder and nonnegligent  \
# 3   1997  267783607       1636096                611                   18208
# 4   1998  270248003       1533887              567.6                   16974
# 5   1999  272690813       1426044                523                   15522
# 6   2000  281421906       1425486              506.5                   15586
# 7   2001  285317559       1439480              504.5                   16037
# 8   2002  287973924       1423677              494.4                   16229
# 9   2003  290788976       1383676              475.8                   16528
# 10  2004  293656842       1360088              463.2                   16148
# 11  2005  296507061       1390745                469                   16740
# 12  2006  299398484       1435123              479.3                   17309
# 13  2007  301621157       1422970              471.8                   17128
# ...

# %%
df.dtypes
# Out:
# Year                            object
# Population                      object
# Violent Crime                   object
# Violent Crime Rate              object
# Murder and nonnegligent         object
# Murder and nonnegligent Rate    object
# Rape                            object
# Rape Rate                       object
# Rape Legacy                     object
# Rape Legacy Rate                object
# Robbery                         object
# Robbery Rate                    object
# Aggravated assault              object
# Aggravated assault Rate         object
# Property crime                  object
# Property crime Rate             object
# Burglary                        object
# Burglary Rate                   object
# Larceny-theft                   object
# Larceny-theft Rate              object
# Motor vehicle theft             object
# Motor vehicle theft Rate        object
# dtype: object

# %%
df['Year'] = df['Year'].astype(str).astype('int')

# %%
df.to_excel('df_crime.xlsx', sheet_name='Crime Data')
